# %% [markdown]
# ## Work
# 1. 請自行定義一個 loss function, 為 0.3 * focal loss + 0.7 cross-entropy，訓練並比較結果

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## hyper params setting
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
import tensorflow as tf
import keras.backend as K

def focal_loss_fixed(y_true, y_pred, gamma=2., alpha=4.):
    """Focal loss for multi-classification
    FL(p_t)=-alpha(1-p_t)^{gamma}ln(p_t)
    """
    epsilon = 1e-8
    y_true = tf.convert_to_tensor(y_true, tf.float32)
    y_pred = tf.convert_to_tensor(y_pred, tf.float32)

    model_out = tf.add(y_pred, epsilon)
    ce = tf.multiply(y_true, -tf.math.log(model_out))
    weight = tf.multiply(y_true, tf.pow(tf.subtract(1., model_out), gamma))
    fl = tf.multiply(alpha, tf.multiply(weight, ce))
    reduced_fl = tf.reduce_max(fl, axis=1)
    return tf.reduce_mean(reduced_fl)

def combined_loss(y_true, y_pred, ce_weight=0.7):
    loss1 = focal_loss_fixed(y_true, y_pred)
    loss2 = K.categorical_crossentropy(y_true, y_pred)
    return (1-ce_weight) * loss1 + ce_weight * loss2

ce_weights_list = [0., 0.3, 0.5, 0.7, 1]

# %%
import itertools
results = {}

for i, ce_w in enumerate(ce_weights_list):
    print("Numbers of exp: %i, ce_weight: %.2f" % (i, ce_w))

    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    
    model.compile(loss=combined_loss, metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True
             )
    
    # Collect results
    exp_name_tag = ("exp-%s" % (i))
    results[exp_name_tag] = {'train-loss': model.history.history["loss"],
                             'valid-loss': model.history.history["val_loss"],
                             'train-acc': model.history.history["accuracy"],
                             'valid-acc': model.history.history["val_accuracy"]}
# Out:
# Numbers of exp: 0, ce_weight: 0.00
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input
# Epoch 20/25
# 50000/50000 [==============================] - 14s 279us/step - loss: 1.2901 - accuracy: 0.6905 - val_loss: 2.2494 - val_accuracy: 0.4901
# Epoch 21/25
# 50000/50000 [==============================] - 14s 277us/step - loss: 1.2429 - accuracy: 0.7010 - val_loss: 2.2412 - val_accuracy: 0.4966
# Epoch 22/25
# 50000/50000 [==============================] - 14s 279us/step - loss: 1.1974 - accuracy: 0.7112 - val_loss: 2.2272 - val_accuracy: 0.4960
# Epoch 23/25
# 50000/50000 [==============================] - 14s 289us/step - loss: 1.1552 - accuracy: 0.7197 - val_loss: 2.2482 - val_accuracy: 0.4917
# Epoch 24/25
# 50000/50000 [==============================] - 14s 290us/step - loss: 1.1162 - accuracy: 0.7312 - val_loss: 2.2709 - val_accuracy: 0.4918
# Epoch 25/25
# 50000/50000 [==============================] - 14s 282us/step - loss: 1.0697 - accuracy: 0.7423 - val_loss: 2.2956 - val_accuracy: 0.4904
# Numbers of exp: 4, ce_weight: 1.00
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 15s 306us/step - loss: 3.4523 - accuracy: 0.2989 - val_loss: 3.4479 - val_accuracy: 0.2121
# Epoch 2/25
# 50000/50000 [==============================] - 17s 347us/step - loss: 2.5681 - accuracy: 0.4172 - val_loss: 3.0599 - val_accuracy: 0.3151
# Epoch 3/25
# 50000/50000 [==============================] - 14s 289us/step - loss: 2.3553 - accuracy: 0.4595 - val_loss: 2.7759 - val_accuracy: 0.3917
# Epoch 4/25
# 50000/50000 [==============================] - 15s 296us/step - loss: 2.2220 - accuracy: 0.4874 - val_loss: 2.6018 - val_accuracy: 0.4203
# Epoch 5/25
# 50000/50000 [==============================] - 15s 296us/step - loss: 2.1202 - accuracy: 0.5096 - val_loss: 2.4379 - val_accuracy: 0.4434
# Epoch 6/25
# 50000/50000 [==============================] - 17s 336us/step - loss: 2.0366 - accuracy: 0.5263 - val_loss: 2.3568 - val_accuracy: 0.4588
# Epoch 7/25
# 50000/50000 [==============================] - 15s 301us/step - loss: 1.9642 - accuracy: 0.5404 - val_loss: 2.3086 - val_accuracy: 0.4645
# Epoch 8/25
# 50000/50000 [==============================] - 14s 275us/step - loss: 1.8947 - accuracy: 0.5566 - val_loss: 2.2910 - val_accuracy: 0.4673
# Epoch 9/25
# 50000/50000 [==============================] - 15s 292us/step - loss: 1.8350 - accuracy: 0.5684 - val_loss: 2.2380 - val_accuracy: 0.4794
# Epoch 10/25
# 50000/50000 [==============================] - 12s 234us/step - loss: 1.7719 - accuracy: 0.5836 - val_loss: 2.2253 - val_accuracy: 0.4799
# Epoch 11/25
# 50000/50000 [==============================] - 13s 262us/step - loss: 1.7170 - accuracy: 0.5946 - val_loss: 2.2559 - val_accuracy: 0.4727
# Epoch 12/25
# 50000/50000 [==============================] - 12s 232us/step - loss: 1.6644 - accuracy: 0.6080 - val_loss: 2.2010 - val_accuracy: 0.4813
# Epoch 13/25
# 50000/50000 [==============================] - 12s 245us/step - loss: 1.6102 - accuracy: 0.6201 - val_loss: 2.2081 - val_accuracy: 0.4840
# Epoch 14/25
# 50000/50000 [==============================] - 10s 206us/step - loss: 1.5580 - accuracy: 0.6304 - val_loss: 2.2070 - val_accuracy: 0.4886
# Epoch 15/25
# 50000/50000 [==============================] - 16s 313us/step - loss: 1.5098 - accuracy: 0.6424 - val_loss: 2.2315 - val_accuracy: 0.4815
# Epoch 16/25
# 50000/50000 [==============================] - 16s 328us/step - loss: 1.4627 - accuracy: 0.6498 - val_loss: 2.1976 - val_accuracy: 0.4906
# Epoch 17/25
# 50000/50000 [==============================] - 15s 293us/step - loss: 1.4108 - accuracy: 0.6625 - val_loss: 2.2368 - val_accuracy: 0.4865
# Epoch 18/25
# 50000/50000 [==============================] - 14s 285us/step - loss: 1.3673 - accuracy: 0.6709 - val_loss: 2.2364 - val_accuracy: 0.4933
# Epoch 19/25
# 50000/50000 [==============================] - 14s 284us/step - loss: 1.3197 - accuracy: 0.6845 - val_loss: 2.2849 - val_accuracy: 0.4846
# Epoch 20/25
# 50000/50000 [==============================] - 14s 289us/step - loss: 1.2733 - accuracy: 0.6953 - val_loss: 2.2476 - val_accuracy: 0.4862
# Epoch 21/25
# 50000/50000 [==============================] - 14s 286us/step - loss: 1.2265 - accuracy: 0.7067 - val_loss: 2.2701 - val_accuracy: 0.4865
# Epoch 22/25
# 50000/50000 [==============================] - 14s 287us/step - loss: 1.1882 - accuracy: 0.7137 - val_loss: 2.2898 - val_accuracy: 0.4909
# Epoch 23/25
# 50000/50000 [==============================] - 14s 276us/step - loss: 1.1363 - accuracy: 0.7280 - val_loss: 2.2767 - val_accuracy: 0.4887
# Epoch 24/25
# 50000/50000 [==============================] - 14s 280us/step - loss: 1.0954 - accuracy: 0.7380 - val_loss: 2.3038 - val_accuracy: 0.4897
# Epoch 25/25
# 50000/50000 [==============================] - 14s 284us/step - loss: 1.0562 - accuracy: 0.7493 - val_loss: 2.3406 - val_accuracy: 0.4805

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
# %matplotlib inline
NUM_COLORS = len(results.keys())

cm = plt.get_cmap('gist_rainbow')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(NUM_COLORS)]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
